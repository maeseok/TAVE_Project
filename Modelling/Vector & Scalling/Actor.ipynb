# %% [markdown]
# # 폴더 순회 후 이목구비 벡터값 res에 저장

# %%
pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (19.24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from face_recognition) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face_recognition) (9.4.0)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=fee62b9fe33e77c7e70e8134fc7a3021eda6e39862dea593a77da3857ecb204d
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face_recognition
# Successfully installed face-recognition-models-0.3.0 face_recognition-1.3.0

# %%
import os
import face_recognition
import zipfile
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 다운로드한 데이터셋의 파일명 (압축 파일)
zip_file_name = "여자배우(최종).zip"

# 압축 파일의 경로
zip_file_path = f"/content/drive/MyDrive/여자배우.zip"

# 데이터셋을 다운로드한 경로
dataset_download_path = "/content/여자배우2"

# 다운로드한 압축 파일을 사용하여 데이터셋을 압축 해제
with zipfile.ZipFile(zip_file_path, "r") as zip_ref:
    zip_ref.extractall(dataset_download_path)

# 압축 파일 삭제 (선택사항)
#os.remove(zip_file_path)

# 데이터셋 폴더 내용 확인
# !ls $dataset_download_path
# Out:
#  고아성_수정본	 강수진_수정본	 강민경_수정본	 고준희_수정본	 강나언_수정본
#  강민아_수정본	 강부자_수정본	 고민시_수정본	 견미리_수정본	 강혜정_수정본
#  갈소원_수정본	 강한나_수정본	 강예원_수정본	 고윤정_수정본	 강소라_수정본
#  고두심_수정본	 고아라_수정본	 경수진_수정본	 고소영_수정본	'고은아 1988년생_수정본'

# %%
# 상위 폴더 경로
parent_folder = '/content/여자배우'

# 상위 폴더 안의 모든 폴더를 순회
res = []
Act_List=os.listdir(parent_folder)
Act_List.sort()

for folder_name in Act_List:
    # 각각의 배우 폴더 경로 설정
    actor_folder = os.path.join(parent_folder, folder_name)

    # 배우 폴더 안의 사진 파일들의 경로 목록 가져오기
    photo_files = [os.path.join(actor_folder, file) for file in os.listdir(actor_folder)]
    photo_files.sort()
    folder_name=folder_name.split("_")
    # 사진 파일들을 로드하여 얼굴 및 이목구비 검출
    print(folder_name)
    face_landmarks_list = [folder_name[0]]
    print(face_landmarks_list)

    for photo_file in photo_files:
       try:
            # 이미지 로드
            image = face_recognition.load_image_file(photo_file)

            # 얼굴 검출
            face_locations = face_recognition.face_locations(image)

            if len(face_locations) > 0:  # 얼굴이 검출되었을 때만 처리
                # 얼굴 및 이목구비 검출
                face_landmarks = face_recognition.face_landmarks(image, face_locations=face_locations)

                if len(face_landmarks) > 0:  # 랜드마크가 검출되었을 때만 처리
                    # 31번 랜드마크 좌표값 가져오기
                    move_x, move_y = face_landmarks[0]['nose_bridge'][3]

                    # 랜드마크 조정
                    adjusted_landmarks = {}
                    for feature, landmarks in face_landmarks[0].items():
                        adjusted_feature = [(x - move_x, y - move_y) for x, y in landmarks]
                        adjusted_landmarks[feature] = adjusted_feature

            # 조정된 랜드마크를 리스트에 추가
            face_landmarks_list.append(adjusted_landmarks)
       except IsADirectoryError:
            pass

    res.append(face_landmarks_list)
# Out:
# ['배두나', '수정본']
# ['배두나']
# ['배수지', '수정본']
# ['배수지']
# ['배종옥', '수정본']
# ['배종옥']

# %% [markdown]
# # JSON 저장

# %%
import json
# 얼굴 랜드마크 정보를 .txt 파일에 저장 (로컬 경로 사용)
output_file_path = 'output_file.txt'  # 현재 작업 디렉터리에 저장
with open(output_file_path, 'w') as output_file:
    json.dump(res, output_file)

# %% [markdown]
# # JSON 읽기

# %%
import json
# 얼굴 랜드마크 정보를 .txt 파일에 저장 (로컬 경로 사용)
Data=[]
Data1=[]
with open('output_file (1).txt', 'r') as file:
    Data1 = json.load(file)

Data2=[]
with open('output_file (2).txt', 'r') as file:
    Data2 = json.load(file)
Data3=[]
with open('output_file (3).txt', 'r') as file:
    Data3 = json.load(file)

Data1.append(Data2)
Data1.append(Data3)


X = []
y = []
for actor in Data1 : # 모든 배우 순회
    print(actor[0])
    for i in range(1,len(actor)) : # 배우 내 이미지 수 만큼
        num = []
        for key, landmark in actor[i].items(): # 벡터값만 추출
            for tup in landmark:
                num.extend(tup)
        X.append(num)
        y.append(actor[0])
    print(X)
    print(y)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9b8b9288fe46> in <cell line: 21>()
#      23     for i in range(1,len(actor)) : # 배우 내 이미지 수 만큼
#      24         num = []
# ---> 25         for key, landmark in actor[i].items(): # 벡터값만 추출
#      26             for tup in landmark:
#      27                 num.extend(tup)
#
# AttributeError: 'list' object has no attribute 'items'

# %%
fixed_X = []
for i in range(len(X)) :
    x_coords = np.array(X[i][::2])
    y_coords = np.array(X[i][1::2])
    '''center_x = np.mean(x_coords)
    center_y = np.mean(y_coords)'''
    fixed_x = x_coords
    fixed_y = y_coords

    fixed_X.append([coord for pair in zip(fixed_x, fixed_y) for coord in pair])

# %%
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# 학습 및 테스트 데이터로 분할
X_train, X_test, y_train, y_test = train_test_split(fixed_X, y, test_size=0.2, random_state=42)

# SVM 분류기 초기화
clf = svm.SVC(kernel='linear')

# 모델 학습
clf.fit(X_train, y_train)

# 테스트 데이터로 예측
y_pred = clf.predict(X_test)

# 정확도 출력
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8495934959349594
